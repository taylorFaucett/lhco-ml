# %%
import h5py
import matplotlib.pyplot as plt
import numpy as np
import pathlib
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable
path = pathlib.Path.cwd()
plt.rcParams['font.family'] = 'serif'
plt.rcParams['figure.autolayout'] = True
plt.rcParams.update({'font.size': 12})

# %%
def plot_jet_images(bbx, N=None):
    hf_file = path.parent / "data" / "jet_images" / f"jet_images_chan_1-{bbx}.h5"
    if hf_file.exists():
        hf = h5py.File(hf_file, "r")
        cmap = "jet"
        images = [np.zeros((32,32,1)), np.zeros((32,32,1)), np.zeros((32,32,1))]
        jet_images = hf["features"][:N]
        targets = hf["targets"][:N].astype(np.int8)
        for X, y in zip(jet_images, targets):
            images[y] += X
        fig, ax = plt.subplots(1, 3, figsize=(12,4), sharex=True, sharey=True)
        for ix, image in enumerate(images):
            image /= np.sum(image)
            vmin = 1e-5
            vmax = np.max(image)
            im = ax[ix].imshow(image, norm=LogNorm(), cmap=cmap)
            title = f"y={ix}"
            if np.sum(image) == 0:
                title = "N/A"
            ax[ix].set_title(title)
            axx = [-0.4, -0.2, 0, 0.2, 0.4]
            ayy = [-0.4, -0.2, 0, 0.2, 0.4]
            ax[ix].xaxis.set_major_locator(plt.MaxNLocator(4))
            ax[0].yaxis.set_major_locator(plt.MaxNLocator(4))
            ax[0].set_yticklabels(axx)
            ax[ix].set_xticklabels(axx)
            ax[ix].set_xlabel("$\eta$")
            ax[0].set_ylabel("$\phi$")
        plt.savefig(path.parent / "figures" / "jet_images" / "png" / f"jet_images-{bbx}.png")
        plt.savefig(path.parent / "figures" / "jet_images" / "pdf" / f"jet_images-{bbx}.pdf")
        hf.close()

for bbx in ("bb1", "bb3"):
    plot_jet_images(bbx)
# Out:
# <ipython-input-5-554c92963f86>:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels(axx)
# <ipython-input-5-554c92963f86>:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[ix].set_xticklabels(axx)
# <ipython-input-5-554c92963f86>:13: RuntimeWarning: invalid value encountered in true_divide
#   image /= np.sum(image)
# /home/tfaucett/miniconda3/envs/tf/lib/python3.8/site-packages/matplotlib/image.py:446: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /home/tfaucett/miniconda3/envs/tf/lib/python3.8/site-packages/matplotlib/image.py:453: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /home/tfaucett/miniconda3/envs/tf/lib/python3.8/site-packages/matplotlib/image.py:458: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# ...
